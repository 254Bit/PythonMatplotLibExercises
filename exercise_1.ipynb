# %% [markdown]
# # Python Matplotlib Exercise

# %% [markdown]
# Read total profit of all months and show it using a line plot.
# Total profit data provided for each month. Generated line plot must include the following properties:-
# x label name = Month Number
# y label name = Total Profit

# %%
import pandas as pd
import matplotlib.pyplot as plt


sales_data=pd.read_csv('FMCG.csv')
sales_data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
import numpy as np

# %%
monthList=sales_data['month_number'].tolist()
profitList=np.arange(100000,500000,500000).tolist()

# %%
plt.plot('month_number','total_profit', data=sales_data)
plt.xlabel('Month Number')
plt.xticks(monthList)
plt.yticks(profitList)
plt.ylabel('Total Profit')
plt.title('Company Profit Per Month')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Get total profit of all months and show line plot with the following Style properties
# #Generated line plot must include following Style properties: –
# #Line Style dotted and Line-color should be red
# #Show legend at the lower right location.
# #label name = Month Number
# #label name = Sold units number
# #Add a circle marker.
# #Line marker color as read
# #Line width should be 3

# %%
plt.plot('month_number', 'total_profit', data=sales_data, color='blue', marker='o', markerfacecolor ='tab:blue', linewidth=3, markersize =6)
plt.xlabel('Month Number')
plt.xticks(monthList)
plt.ylabel('Total Profit')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.legend(loc='upper left')
plt.title('COMPANY SALES FOR LAST YEAR')
plt.show()

# %%
sales_data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
quantityList=np.arange(1000,20000,2000)

# %%
plt.plot('month_number','facecream',data=sales_data,marker='o')
plt.plot('month_number','facewash',data=sales_data,marker='o')
plt.plot('month_number','toothpaste',data=sales_data,marker='o')
plt.plot('month_number','bathingsoap',data=sales_data,marker='o')
plt.plot('month_number','shampoo',data=sales_data,marker='o')
plt.plot('month_number','moisturizer',data=sales_data,marker='o')

plt.xticks(monthList)
plt.xlabel('Month Number')
plt.yticks(quantityList)
plt.ylabel('Sales of product (number of units)')
plt.legend(loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Read toothpaste sales data of each month and show it using a scatter plot
plt.scatter('month_number','toothpaste', data=sales_data)
plt.legend(loc='upper left')
plt.grid(color='r', linestyle='dashed', linewidth=0.5)
plt.xlabel('Month Number')
plt.ylabel('Quantity Sales')
plt.show()

# %%
# Read face cream and facewash product sales data and show it using the bar chart
#The bar chart should display the number of units sold per month for each product. 
# Add a separate bar for each product in the same chart.

plt.bar([a-0.25 for a in monthList], 'facecream',data=sales_data,width=0.25,align='edge',label = 'Face Cream sales data',)
plt.bar([a-0.25 for a in monthList], 'facewash',data=sales_data,width=0.25,align='edge', label = 'Face Wash sales data',)

plt.xticks(monthList)
plt.xlabel('Month Number')
plt.ylabel('Quantity Sales')
plt.legend()
plt.grid(color='r', linestyle='dashed', linewidth=0.2)
plt.show()

# %%
# Read sales data of bathing soap of all months and show it using a bar chart. 
# Save this plot to your hard disk
plt.bar('month_number','total_units',data=sales_data)
plt.grid(True, linestyle='dashed')
plt.xticks(monthList)
plt.xlabel('Month Number')
plt.ylabel('Sales unit in numbers')
plt.title('Bathing Soap Sales Data')
plt.show()

# %% [markdown]
# # Read the total profit of each month and show it using the histogram to see the most common profit ranges

# %%
profitList=sales_data['total_profit'].tolist()

# %%
profit_range=np.arange(150000,350000,25000)

# %%
plt.hist(profitList,profit_range,label='max profit range')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  #Calculate total sale data for last year for each product and show it using a Pie chart

# %%
sales_data.head(2)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300

# %%
saleData=[sales_data['facecream'].sum(),sales_data['facewash'].sum(),sales_data['toothpaste'].sum(),sales_data['bathingsoap'].sum(),sales_data['shampoo'].sum(),sales_data['moisturizer'].sum()]
saleData
# Out:
# [34480, 18515, 69910, 114010, 25410, 18515]

# %%
labels=['Face Cream','Face Wash','Toothpaste','Bathing Soap','Shampoo','Moisturizer']

# %%
plt.pie(saleData,autopct='%1.1f%%',labels=labels)
plt.legend()
plt.show()

# %%
# Read Bathing soap and facewash of all months and display it using the Subplot
plt.subplot(2,1,1)
plt.plot('month_number','bathingsoap',data=sales_data,color='blue',marker='o')
plt.title('Sales data of Bathing Soap')

plt.subplot(2,1,2)
plt.plot('month_number','facewash',data=sales_data,color='red',marker='o')
plt.xlabel('Month Number')
plt.title('Sales Data of Face wash')
plt.ylabel('Sales unit in numbers')

plt.subplots_adjust(bottom=0.1,wspace=0.4,hspace=0.3)

plt.show()
